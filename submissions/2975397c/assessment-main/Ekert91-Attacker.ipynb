# %%
from qiskit import QuantumCircuit
from qiskit.converters import circuit_to_gate
from qiskit.visualization import array_to_latex
from qiskit.quantum_info import Operator
from qiskit.quantum_info import Statevector
from qiskit import transpile 
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram
from qiskit.circuit import ControlledGate
import importlib
import e91
importlib.reload(e91)
from e91 import *
import math

# %%
measurements = protocol(100, attacker=True)
valid_measurements, bell_test_measurements, discarded_measurements = measurement_parsing(measurements)
bell_test(bell_test_measurements)
alice_key_bits, bob_key_bits = key_builder(valid_measurements)
print("Alice's key: ", alice_key_bits)
print("Bob's key: ", bob_key_bits)
print("Keys Match: ", alice_key_bits == bob_key_bits)
# Out:
# Bell inequality not violated! S = 1.9960424395985639 possible attacker detected
# Alice's key length:  109
# Bob's key length:  109
# Keys Match:  False
